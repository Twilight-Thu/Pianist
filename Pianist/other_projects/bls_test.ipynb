# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
path = "/content/drive/MyDrive/bls/"
os.chdir(path)

# %%
# !pip install numpy
# !pip install scipy
# !pip install keras
# !pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python Demo4BLS.py
# Out:
# -------------------BLS_BASE---------------------------
# Training accurate is 96.385 %
# Training time is  10.670028686523438 s
# Testing accurate is 96.26 %
# Testing time is  0.7230072021484375 s
# -------------------BLS_ENHANCE------------------------
# Training accurate is 96.385 %
# Training time is  10.501494407653809 s
# Testing accurate is 96.26 %
# Testing time is  0.4681968688964844 s
# Incremental Training Accuracy is : 96.56  %
# Incremental Testing Accuracy is :  96.49  %
# Incremental Training Accuracy is : 96.673  %
# Incremental Testing Accuracy is :  96.53  %
# Incremental Training Accuracy is : 96.83  %
# Incremental Testing Accuracy is :  96.69  %
# Incremental Training Accuracy is : 96.892  %
# Incremental Testing Accuracy is :  96.78999999999999  %
# Incremental Training Accuracy is : 96.928  %
# Incremental Testing Accuracy is :  96.77  %
# -------------------BLS_FEATURE&ENHANCE----------------
# Training accurate is 95.143 %
# ...
