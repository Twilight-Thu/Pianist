# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
path = "/content/drive/MyDrive/Image-based-PM2.5-Estimation-main/"
os.chdir(path)
# !pip install thop
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# pred_dir: ./images_rotate/
# Load model:  ./SingleNet/MobileNetV2.pk
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#  20200111095913928.jpg
# Estimated PM2.5:  tensor([5.0007], device='cuda:0')
# Traceback (most recent call last):
# ...

# %%
# !python SingleNet/test.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#  20190831091244174.jpg
# Estimated PM2.5:  tensor([7.6254], device='cuda:0')
#  20190831111430682.jpg
# Estimated PM2.5:  tensor([10.8776], device='cuda:0')
#  20190831084217900.jpg
# Estimated PM2.5:  tensor([9.5377], device='cuda:0')
#  20190831061005822.jpg
# Estimated PM2.5:  tensor([10.4837], device='cuda:0')
#  20190831121525300.jpg
# Estimated PM2.5:  tensor([8.7253], device='cuda:0')
#  20190901053441182.jpg
# Estimated PM2.5:  tensor([20.4219], device='cuda:0')
#  20190901070559976.jpg
# Estimated PM2.5:  tensor([23.6006], device='cuda:0')
#  20190831134646401.jpg
# Estimated PM2.5:  tensor([9.7894], device='cuda:0')
#  20190831154834047.jpg
# Estimated PM2.5:  tensor([7.7356], device='cuda:0')
#  20190901080652562.jpg
# Estimated PM2.5:  tensor([23.4462], device='cuda:0')
#  20190901060507440.jpg
# Estimated PM2.5:  tensor([21.8536], device='cuda:0')
#  20190901073626328.jpg
# Estimated PM2.5:  tensor([21.0560], device='cuda:0')
# ...
